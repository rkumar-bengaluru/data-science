# %%
#Basic Libraries
import numpy as np
import pandas as pd

#Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#Text Handling Libraries
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# clustering
from sklearn.cluster import KMeans

#
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
# Function for removing NonAscii characters
def _removeNonAscii(s):
    return "".join(i for i in s if  ord(i)<128)

# Function for converting into lower case
def make_lower_case(text):
    return text.lower()

# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# Function for removing the html tags
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# recommendation
def get_recommendation(title, sim,products,indices):
    idx = indices[title]
    sim_scores = list(enumerate(sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    product_indices = [i[0] for i in sim_scores]
    return products.iloc[product_indices]

# %%
df = pd.read_csv('data/zue_all_materials.csv')
df['zzibrnd'] = df['zzibrnd'].astype(str)
df['TherapeuticClass'] = df['TherapeuticClass'].astype(str)
df['PrincipalName'] = df['PrincipalName'].astype(str)
df['Description'] = df['Description'].astype(str)
df['zzibrnd'] = df['Description'].astype(str)
df['GenericMaterialName'] = df['Description'].astype(str)
df.info()
# Out:
# C:\Users\rupak\AppData\Local\Temp\ipykernel_13084\2365512333.py:1: DtypeWarning: Columns (0,14,15,17,20,22,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/zue_all_materials.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220901 entries, 0 to 220900
# Data columns (total 50 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   matnr                       220901 non-null  object
#  1   zzprncode                   220852 non-null  float64
#  2   zzibrnd                     220901 non-null  object
#  3   mtart                       220901 non-null  object
#  4   matkl                       220898 non-null  object
#  5   TherapeuticClass            220901 non-null  object
#  6   PrincipalName               220901 non-null  object
#  7   mstae                       213974 non-null  object
#  8   mstde                       220901 non-null  int64
#  9   mstav                       153406 non-null  object
#  10  mstdv                       220901 non-null  int64
#  11  zzdwrx                      220901 non-null  object
#  12  spart                       220848 non-null  float64
#  13  vtweg                       220901 non-null  int64
#  14  dwerk                       212581 non-null  object
#  15  mvgr1                       12251 non-null   object
#  16  mvgr2                       1067 non-null    float64
#  17  mvgr3                       15088 non-null   object
#  18  mvgr4                       218281 non-null  object
#  19  mvgr5                       28090 non-null   float64
#  20  vmsta                       783 non-null     object
#  21  vmstd                       220901 non-null  int64
#  22  MaterialSalesOrganisation   220901 non-null  object
#  23  prodh                       220860 non-null  object
#  24  mtpos                       219716 non-null  object
#  25  OldMaterialCode             214727 non-null  object
#  26  GovernmentMaterialCode      20663 non-null   object
#  27  taxClassification           0 non-null       float64
#  28  Description                 220901 non-null  object
#  29  Language                    220901 non-null  object
#  30  DefaultMaterialDescription  220890 non-null  object
#  31  DefaultMaterialLanguage     220901 non-null  object
#  32  unitOfMeasurement           220901 non-null  object
#  33  itemRegistrationNumber      117931 non-null  object
#  34  GenericMaterialName         220901 non-null  object
#  35  WarehouseStorageCondition   177720 non-null  object
#  36  aland                       215057 non-null  object
#  37  taxm1                       215057 non-null  float64
#  38  taxm2                       0 non-null       float64
#  39  taxm3                       0 non-null       float64
#  40  taxm4                       0 non-null       float64
#  41  taxm5                       0 non-null       float64
#  42  taxm6                       0 non-null       float64
#  43  taxm7                       0 non-null       float64
#  44  taxm8                       0 non-null       float64
#  45  taxm9                       0 non-null       float64
#  46  taxim                       0 non-null       float64
#  47  tatyp                       215057 non-null  object
#  48  vtext                       215057 non-null  object
#  49  idnlf                       186541 non-null  object
# dtypes: float64(15), int64(4), object(31)
# memory usage: 84.3+ MB

# %%
df['matnr'] = df['matnr'].drop_duplicates()
df
# Out:
#            matnr  zzprncode                            zzibrnd mtart matkl  \
# 0       26095737   102521.0      QIAxcel, Basic Agreement,o PM  ZF06   ZMD
# 1       23265332   102544.0       DELTA C-TAPER HEAD 28mm -2.5  ZF03   ZMD
# 2       23265333   102544.0         DELTA C-TAPER HEAD 32mm +0  ZF03   ZMD
# 3       23265334   102544.0         DELTA C-TAPER HEAD 32mm +5  ZF03   ZMD
# 4       23265335   102544.0       DELTA C-TAPER HEAD 32mm +2.5  ZF03   ZMD
# ...          ...        ...                                ...   ...   ...
# 220896       NaN   102017.0                人類上皮因子接受體第二蛋白陽性玻片　　  ZF03   ZMD
# 220897       NaN   102017.0       *PATHWAT HER2/NEU4IN   1'Kit  ZF03   ZMD
# 220898       NaN   102017.0                ＨＥＲ人類上皮細胞接受器用一級抗體　　  ZF03   ZMD
# 220899       NaN   102017.0  Path. Anti-Her-2/NEU  50Test 1'PC  ZF03   ZMD
# 220900  21129350   102709.0              CONCOR TAB 5MG 3x10'S  ZF01   ZPE
#
#                    TherapeuticClass             PrincipalName mstae     mstde  \
# 0                Non-IMS classified  QIAGEN SINGAPORE PTE LTD    LR  20460101
# 1                Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231
# 2                Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231
# 3                Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231
# 4                Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231
# ...                             ...                       ...   ...       ...
# 220896           Non-IMS classified           台灣羅氏醫療診斷設備(股)公司    LR  99901231
# 220897           Non-IMS classified           台灣羅氏醫療診斷設備(股)公司    LR  99901231
# 220898           Non-IMS classified           台灣羅氏醫療診斷設備(股)公司    LR  99901231
# 220899           Non-IMS classified           台灣羅氏醫療診斷設備(股)公司    LR  99901231
# 220900  Beta-blocking agents, plain         Merck Export GmbH    DS  20210420
#
#        mstav  ...  taxm4 taxm5  taxm6  taxm7 taxm8 taxm9  taxim tatyp  \
# 0         LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 1         LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 2         LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 3         LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 4         LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# ...      ...  ...    ...   ...    ...    ...   ...   ...    ...   ...
# 220896    LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 220897    LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 220898    LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 220899    LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
# 220900    LR  ...    NaN   NaN    NaN    NaN   NaN   NaN    NaN  MWST
#
#                      vtext        idnlf
# 0       Product : Full Tax      9241203
# 1       Product : Full Tax        18283
# 2       Product : Full Tax       183200
# 3       Product : Full Tax       183205
# 4       Product : Full Tax       183225
# ...                    ...          ...
# 220896  Product : Full Tax  05273510001
# 220897  Product : Full Tax  05273510001
# 220898  Product : Full Tax  05278368001
# 220899  Product : Full Tax  05278368001
# 220900  Product : Full Tax          NaN
#
# [220901 rows x 50 columns]

# %%
df_clean = df.reset_index()
brands = df_clean['zzibrnd']
indices = pd.Series(df_clean.index, index=df_clean['zzibrnd'])
df_clean.head()
# Out:
#    index     matnr  zzprncode                        zzibrnd mtart matkl  \
# 0      0  26095737   102521.0  QIAxcel, Basic Agreement,o PM  ZF06   ZMD
# 1      1  23265332   102544.0   DELTA C-TAPER HEAD 28mm -2.5  ZF03   ZMD
# 2      2  23265333   102544.0     DELTA C-TAPER HEAD 32mm +0  ZF03   ZMD
# 3      3  23265334   102544.0     DELTA C-TAPER HEAD 32mm +5  ZF03   ZMD
# 4      4  23265335   102544.0   DELTA C-TAPER HEAD 32mm +2.5  ZF03   ZMD
#
#      TherapeuticClass             PrincipalName mstae     mstde  ... taxm4  \
# 0  Non-IMS classified  QIAGEN SINGAPORE PTE LTD    LR  20460101  ...   NaN
# 1  Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231  ...   NaN
# 2  Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231  ...   NaN
# 3  Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231  ...   NaN
# 4  Non-IMS classified   Stryker (Thailand) Ltd.    LR  99901231  ...   NaN
#
#    taxm5 taxm6  taxm7  taxm8 taxm9 taxim  tatyp               vtext    idnlf
# 0    NaN   NaN    NaN    NaN   NaN   NaN   MWST  Product : Full Tax  9241203
# 1    NaN   NaN    NaN    NaN   NaN   NaN   MWST  Product : Full Tax    18283
# 2    NaN   NaN    NaN    NaN   NaN   NaN   MWST  Product : Full Tax   183200
# 3    NaN   NaN    NaN    NaN   NaN   NaN   MWST  Product : Full Tax   183205
# 4    NaN   NaN    NaN    NaN   NaN   NaN   MWST  Product : Full Tax   183225
#
# [5 rows x 51 columns]

# %%
df_clean['soup'] = df_clean['Description'] 
df_clean['soup'][0]
# Out:
# 'QIAxcel, Basic Agreement,o PM'

# %%
# Applying all the functions in description and storing as a cleaned_desc
df_clean['soup'] = df_clean['soup'].apply(_removeNonAscii)
df_clean['soup'] = df_clean.soup.apply(func = make_lower_case)
df_clean['soup'] = df_clean.soup.apply(func=remove_punctuation)
df_clean['soup'] = df_clean.soup.apply(func=remove_html)
df_clean['soup'][0]
# Out:
# 'qiaxcel basic agreement o pm'

# %%
df_clean[['soup','zzibrnd']]
# Out:
#                                    soup                            zzibrnd
# 0          qiaxcel basic agreement o pm      QIAxcel, Basic Agreement,o PM
# 1           delta c taper head 28mm 2 5       DELTA C-TAPER HEAD 28mm -2.5
# 2             delta c taper head 32mm 0         DELTA C-TAPER HEAD 32mm +0
# 3             delta c taper head 32mm 5         DELTA C-TAPER HEAD 32mm +5
# 4           delta c taper head 32mm 2 5       DELTA C-TAPER HEAD 32mm +2.5
# ...                                 ...                                ...
# 220896                                                 人類上皮因子接受體第二蛋白陽性玻片
# 220897        pathwat her2 neu4in 1 kit       *PATHWAT HER2/NEU4IN   1'Kit
# 220898                                                 ＨＥＲ人類上皮細胞接受器用一級抗體
# 220899  path anti her 2 neu 50test 1 pc  Path. Anti-Her-2/NEU  50Test 1'PC
# 220900            concor tab 5mg 3x10 s              CONCOR TAB 5MG 3x10'S
#
# [220901 rows x 2 columns]

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df_clean['soup'])
tfidf_matrix.shape
# Out:
# (220901, 187466)

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
#
# File C:\sofware\anaconda3\envs\projects\lib\site-packages\sklearn\metrics\pairwise.py:1073, in linear_kernel(X, Y, dense_output)
#    1048 """
#    1049 Compute the linear kernel between X and Y.
#    1050
#    (...)
#    1070     The Gram matrix of the linear kernel, i.e. `X @ Y.T`.
#    1071 """
#    1072 X, Y = check_pairwise_arrays(X, Y)
# -> 1073 return safe_sparse_dot(X, Y.T, dense_output=dense_output)
#
# File C:\sofware\anaconda3\envs\projects\lib\site-packages\sklearn\utils\extmath.py:161, in safe_sparse_dot(a, b, dense_output)
#     153     ret = a @ b
#     155 if (
#     156     sparse.issparse(a)
#     157     and sparse.issparse(b)
#     158     and dense_output
#     159     and hasattr(ret, "toarray")
#     160 ):
# --> 161     return ret.toarray()
#     162 return ret
#
# File C:\sofware\anaconda3\envs\projects\lib\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File C:\sofware\anaconda3\envs\projects\lib\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 364. GiB for an array with shape (220901, 220901) and data type float64

# %%
searchstr = 'BEPANTHEN FIRST AIDCREAM30G FREE 3.5G'
idx = get_recommendation(searchstr,cosine_sim,brands,indices).values
idx
# Out:
# array(['MENTHOLATUM WATERLIPFRAGRANCE FREE 3.5G',
#        'BEPANTHEN BABY BATHLIQUID200ML', 'BEPANTHEN FIRST AID CREAM 30G',
#        'BEPANTHEN OINT 100GVALUEPACK RM25',
#        'BEPANTHEN OINTMENT 30G TWIN PACK',
#        'BEPANTHEN OINTMENT 30G VPRM10.50',
#        'BEPANTHEN OINT 30G VALUE PACK RM10',
#        'BEPANTHEN OINT 100GFREE 5X7ML BABY BATH', 'THERAPY LIPBALM3.5G',
#        'LIPICE LEMON (NEW)3.5G'], dtype=object)

# %%
df_clean.iloc[['4782']]
# Out:
#       index     matnr  zzprncode                           zzibrnd mtart  \
# 4782   4782  23063718   101363.0  FOLTENE ANTI AGING SHAMPOO 200ML  ZF03
#
#      matkl                   TherapeuticClass   PrincipalName mstae     mstde  \
# 4782   ZCS  Other dermatological preparations  PARVUS SDN BHD    LR  20250120
#
#       ... prat1  prat2 prat3  prat4  prat5  prat6 prat7  prat8 prat9  \
# 4782  ...   NaN    NaN   NaN    NaN    NaN    NaN   NaN    NaN   NaN
#
#                                                    soup
# 4782  foltene anti aging shampoo 200ml parvus sdn bh...
#
# [1 rows x 62 columns]

# %%
df_clean[df_clean['zzibrnd'].isin(idx)]
# Out:
#       index     matnr  zzprncode                                  zzibrnd  \
# 633     633  23064705   101369.0  BEPANTHEN OINT 100GFREE 5X7ML BABY BATH
# 898     898  23064870   101369.0            BEPANTHEN FIRST AID CREAM 30G
# 1407   1407  23064727   101369.0         BEPANTHEN OINTMENT 30G VPRM10.50
# 1683   1683  23064713   101369.0        BEPANTHEN OINT 100GVALUEPACK RM25
# 1752   1752  23064920   101369.0           BEPANTHEN BABY BATHLIQUID200ML
# 2406   2406  23064725   101369.0         BEPANTHEN OINTMENT 30G TWIN PACK
# 2564   2564  23071367   101242.0                   LIPICE LEMON (NEW)3.5G
# 2822   2822  23071373   101242.0  MENTHOLATUM WATERLIPFRAGRANCE FREE 3.5G
# 3158   3158  23064712   101369.0       BEPANTHEN OINT 30G VALUE PACK RM10
# 4348   4348  23071016   101242.0                      THERAPY LIPBALM3.5G
#
#      mtart matkl                TherapeuticClass  \
# 633   ZF03   ZPE  All other wound healing agents
# 898   ZF03   ZPO  All other wound healing agents
# 1407  ZF03   ZPE  All other wound healing agents
# 1683  ZF03   ZCH  All other wound healing agents
# 1752  ZF03   ZCS            Wound healing agents
# 2406  ZF03   ZPE  All other wound healing agents
# 2564  ZF03   ZPC         Emollients, protectives
# 2822  ZF03   ZPC         Emollients, protectives
# 3158  ZF03   ZCH  All other wound healing agents
# 4348  ZF03   ZPC         Emollients, protectives
#
#                       PrincipalName mstae     mstde  ... prat1  prat2 prat3  \
# 633     BAYER CO (MALAYSIA) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 898     BAYER CO (MALAYSIA) SDN BHD    LR  20250413  ...   NaN    NaN   NaN
# 1407    BAYER CO (MALAYSIA) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 1683    BAYER CO (MALAYSIA) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 1752    BAYER CO (MALAYSIA) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 2406    BAYER CO (MALAYSIA) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 2564  ROHTO-MENTHOLATUM (M) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 2822  ROHTO-MENTHOLATUM (M) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 3158    BAYER CO (MALAYSIA) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
# 4348  ROHTO-MENTHOLATUM (M) SDN BHD    LR  20250101  ...   NaN    NaN   NaN
#
#       prat4  prat5  prat6 prat7  prat8 prat9  \
# 633     NaN    NaN    NaN   NaN    NaN   NaN
# 898     NaN    NaN    NaN   NaN    NaN   NaN
# 1407    NaN    NaN    NaN   NaN    NaN   NaN
# 1683    NaN    NaN    NaN   NaN    NaN   NaN
# 1752    NaN    NaN    NaN   NaN    NaN   NaN
# 2406    NaN    NaN    NaN   NaN    NaN   NaN
# 2564    NaN    NaN    NaN   NaN    NaN   NaN
# 2822    NaN    NaN    NaN   NaN    NaN   NaN
# 3158    NaN    NaN    NaN   NaN    NaN   NaN
# 4348    NaN    NaN    NaN   NaN    NaN   NaN
#
#                                                    soup
# 633   bepanthen oint 100gfree 5x7ml baby bath bayer ...
# 898   bepanthen first aid cream 30g bayer co malaysi...
# 1407  bepanthen ointment 30g vprm10 50 bayer co mala...
# 1683  bepanthen oint 100gvaluepack rm25 bayer co mal...
# 1752  bepanthen baby bathliquid200ml bayer co malays...
# 2406  bepanthen ointment 30g twin pack bayer co mala...
# 2564  lipice lemon new 3 5g rohto mentholatum m sdn ...
# 2822  mentholatum waterlipfragrance free 3 5g rohto ...
# 3158  bepanthen oint 30g value pack rm10 bayer co ma...
# 4348  therapy lipbalm3 5g rohto mentholatum m sdn bh...
#
# [10 rows x 62 columns]

# %%
searchstr = '(Z) JANUMET XR 50/1000 TABS 56\'S'
idx = get_recommendation(searchstr,cosine_sim,brands,indices).values
idx
# Out:
# array(["(Z) JANUMET XR 100/1000 TABS 28'S",
#        "(Z) JANUMET HAARLEM TABS 50/1000MG 56'S",
#        "JANUMET HAARLEMTABS50/500MG 56'S",
#        "JANUMET HAARLEMTABS50/1000MG 56'S",
#        "JANUMET HAARLEMTABS50/850MG 56'S", "JANUVIATABS100MG28'S",
#        "GALVUS METTAB 50/850MG60'S", "GALVUS METTAB 50/1000MG60'S",
#        "<GLUCOPHAGE XR TABS500MG4X15'S", "AVANDAMETTAB4MG/500MG 56'S"],
#       dtype=object)

# %%
searchstr = 'BEBELAC INFANT FORMULA STEP 1400G'
idx = get_recommendation(searchstr,cosine_sim,brands,indices).values
idx
# Out:
# array(['BEBELAC INFANT FORMULA STEP 1800G',
#        'DUPRO FOLLOW-UP FORMULA STEP 21KG',
#        'DUPRO FOLLOW-UP FORMULA STEP 2650G',
#        'NEOCATE LCP INFANT FORMULA 400G (MY)\xa0\xa0\xa0\xa0',
#        'DUPRO FOLLOW-UP FORMULA STEP 21.6KG', 'MAMEX CHERISH 1400G',
#        'BEBELAC FOLLOW-UP FORMULASTEP 2800G',
#        'MAMIL STEP 3 1.7KG (MY) WHA\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#        'DULAC INFANT FORMULASTEP 11KG', 'DULAC INFANT FORMULASTEP 1350G'],
#       dtype=object)

# %%
searchstr = 'DUREX PLAY SWEET STRAWBEERY 100ML'
idx = get_recommendation(searchstr,cosine_sim,brands,indices).values
idx
# Out:
# array(['DUREX PLAY WARMING 100ML', "DUREX PLAY 100ML 1'S/BOX",
#        'DUREX PLAY SOOTHINGALOEVERA100ML', 'DUREX PLAY TINGLE100ML',
#        "DUREX PLAY 50ML 1'S/BOX", "DUREX PLAY O 15ML 1'S/BOX",
#        "DUREX PLAY VIBRATINGCONDOM 1'S/BOX",
#        'DUREX PLAY MASSAGE2 IN 1200ML',
#        "DUREX PLAY MASSAGE SENSUALYLANG1'S/BOX",
#        'DUREX LOVE 12SFOC PLAY MSGSACHT'], dtype=object)

# %%
searchstr = 'PPD ESCITALOPRAMTAB10MG28\'S'
idx = get_recommendation(searchstr,cosine_sim,brands,indices).values
idx
# Out:
# array(["PPD QUETIAPINETAB25MG60'S", "PPD QUETIAPINETAB100MG60'S",
#        'PPD BISOPROLOLTAB5MG100S', "PPD BISOPROLOLTAB2.5MG100'S", 'nan',
#        'nan', 'nan', 'PPD AMOXI+CLAVU ACIDTAB 500MG+125MG 100S',
#        "LISDENE UD MYTAB20MG30'S", 'nan'], dtype=object)
