# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Formula
# output_shape = math.floor((input_shape - pool_size) / strides) + 1

# %%
image_file = 'download.png'
img = tf.keras.preprocessing.image.load_img(image_file)

orig_img = tf.keras.preprocessing.image.img_to_array(img)
print(orig_img.shape)
plt.imshow(orig_img)
plt.title('Original Image')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (225, 225, 3)
# Text(0.5, 1.0, 'Original Image')

# %%
max_pool_2d = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))
pooled = max_pool_2d(tf.reshape(image_array,(1,225,225,3)))
print(pooled.shape)
max_pool_2d_image = tf.reshape(pooled,(112,112,3))
print(max_pool_2d_image.shape)
# Out:
# (1, 112, 112, 3)
# (112, 112, 3)

# %%
# show both the images original and max pooled image.
fig,axes = plt.subplots(1,2,figsize=(15,7))
axes[0].imshow(orig_img)
axes[0].set_title('Original')
axes[1].imshow(max_pool_2d_image)
axes[1].set_title('MaxPooling2D')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'MaxPooling2D')

# %%
avg_pool_2d = tf.keras.layers.AveragePooling2D()
avg_pooled = avg_pool_2d(tf.reshape(orig_img,(1,225,225,3)))
print(avg_pooled.shape)
avg_pool_2d_image = tf.reshape(avg_pooled,(112,112,3))
print(avg_pool_2d_image.shape)
# Out:
# (1, 112, 112, 3)
# (112, 112, 3)

# %%
# show both the images original and max pooled image.
fig,axes = plt.subplots(1,2,figsize=(15,7))
axes[0].imshow(orig_img)
axes[0].set_title('Original')
axes[1].imshow(avg_pool_2d_image)
axes[1].set_title('AveragePooling2D')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'AveragePooling2D')

# %%
avg_pool_2d_1 = tf.keras.layers.AvgPool2D()
avg_pooled_1 = avg_pool_2d_1(tf.reshape(orig_img,(1,225,225,3)))
print(avg_pooled_1.shape)
avg_pool_2d_1_image = tf.reshape(avg_pooled_1,(112,112,3))
print(avg_pool_2d_1_image.shape)
# Out:
# (1, 112, 112, 3)
# (112, 112, 3)

# %%
# show both the images original and max pooled image.
fig,axes = plt.subplots(1,2,figsize=(15,7))
axes[0].imshow(orig_img)
axes[0].set_title('Original')
axes[1].imshow(avg_pool_2d_1_image)
axes[1].set_title('AvgPool2D')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'AvgPool2D')

# %%
global_avg_pool_2d = tf.keras.layers.GlobalAveragePooling2D()
global_avg_pooled = global_avg_pool_2d(tf.reshape(orig_img,(1,225,225,3)))
print(global_avg_pooled.shape)
global_avg_pool_2d_image = tf.reshape(global_avg_pooled,(1,3))
print(global_avg_pool_2d_image.shape)
# Out:
# (1, 3)
# (1, 3)

# %%
# show both the images original and max pooled image.
fig,axes = plt.subplots(1,2,figsize=(15,7))
axes[0].imshow(orig_img)
axes[0].set_title('Original')
axes[1].imshow(global_avg_pool_2d_image)
axes[1].set_title('GlobalAveragePooling2D')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'GlobalAveragePooling2D')

# %%
global_max_pool_2d = tf.keras.layers.GlobalMaxPool2D()
global_max_pooled = global_max_pool_2d(tf.reshape(orig_img,(1,225,225,3)))
print(global_max_pooled.shape)
global_max_pool_2d_image = tf.reshape(global_max_pooled,(1,3))
print(global_max_pool_2d_image.shape)
# Out:
# (1, 3)
# (1, 3)

# %%
# show both the images original and max pooled image.
fig,axes = plt.subplots(1,2,figsize=(15,7))
axes[0].imshow(orig_img)
axes[0].set_title('Original')
axes[1].imshow(global_max_pool_2d_image)
axes[1].set_title('GlobalMaxPool2D')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'GlobalMaxPool2D')

# %%
print(tf.__version__)
# Out:
# 2.10.0
