# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Ames_Housing_Data_Missing_Fixed.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1      0
# Unnamed: 0        0
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 78, dtype: int64

# %%
df.shape
# Out:
# (2925, 78)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  MS SubClass MS Zoning  Lot Frontage  Lot Area  \
# 0             0           0           20        RL         141.0     31770
# 1             1           1           20        RH          80.0     11622
# 2             2           2           20        RL          81.0     14267
# 3             3           3           20        RL          93.0     11160
# 4             4           4           60        RL          74.0     13830
#
#   Street Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 0   Pave       IR1          Lvl    AllPub  ...              0          0
# 1   Pave       Reg          Lvl    AllPub  ...              0          0
# 2   Pave       IR1          Lvl    AllPub  ...              0          0
# 3   Pave       Reg          Lvl    AllPub  ...              0          0
# 4   Pave       IR1          Lvl    AllPub  ...              0          0
#
# ...

# %%
df['MS SubClass'] = df['MS SubClass'].apply(str)

# %%
direction = pd.Series(['Up','Up','Down'])

# %%
direction
# Out:
# 0      Up
# 1      Up
# 2    Down
# dtype: object

# %%
pd.get_dummies(direction,drop_first=True)
# Out:
#    Up
# 0   1
# 1   1
# 2   0

# %%
df.select_dtypes(include='object')
# Out:
#      MS SubClass MS Zoning Street Lot Shape Land Contour Utilities Lot Config  \
# 0             20        RL   Pave       IR1          Lvl    AllPub     Corner
# 1             20        RH   Pave       Reg          Lvl    AllPub     Inside
# 2             20        RL   Pave       IR1          Lvl    AllPub     Corner
# 3             20        RL   Pave       Reg          Lvl    AllPub     Corner
# 4             60        RL   Pave       IR1          Lvl    AllPub     Inside
# ...          ...       ...    ...       ...          ...       ...        ...
# 2920          80        RL   Pave       IR1          Lvl    AllPub    CulDSac
# 2921          20        RL   Pave       IR1          Low    AllPub     Inside
# 2922          85        RL   Pave       Reg          Lvl    AllPub     Inside
# 2923          20        RL   Pave       Reg          Lvl    AllPub     Inside
# 2924          60        RL   Pave       Reg          Lvl    AllPub     Inside
#
# ...

# %%
my_object_df = df.select_dtypes(include='object')
my_num_df = df.select_dtypes(exclude='object')

# %%
df_object_dummies = pd.get_dummies(my_object_df,drop_first=True)

# %%
df_object_dummies.shape
# Out:
# (2925, 239)

# %%
final_df = pd.concat([my_num_df,df_object_dummies],axis=1)

# %%
final_df.shape
# Out:
# (2925, 277)

# %%
final_df.to_csv('Ames_Housing_Data_Cleaned.csv')

# %%
final_df.corr()['SalePrice'].sort_values(ascending=True)
# Out:
# Exter Qual_TA       -0.591459
# Kitchen Qual_TA     -0.527461
# Fireplace Qu_None   -0.481740
# Bsmt Qual_TA        -0.453022
# Garage Finish_Unf   -0.422363
#                        ...
# Garage Cars          0.648488
# Total Bsmt SF        0.660983
# Gr Liv Area          0.727279
# Overall Qual         0.802637
# SalePrice            1.000000
# Name: SalePrice, Length: 277, dtype: float64
