# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/customerinformation_all.csv',converters={'kunnr': str})
# Out:
# C:\Users\rupak\AppData\Local\Temp\ipykernel_24376\1791157729.py:1: DtypeWarning: Columns (10,16,17,22,23,24,25,32,37,41,53,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/customerinformation_all.csv',converters={'kunnr': str})

# %%
df.head()
# Out:
#         kunnr defpa     kunn2 parvw  spart  vkorg  vtweg land1 aufsd  \
# 0  0030068160     X  70132214    WE      0   2001     10    MY   NaN
# 1  0030068255     X  70132306    WE      0   2001     10    MY   NaN
# 2  0030068028   NaN  70132016    WE      0   2001     10    MY   NaN
# 3  0030068731     X  70132838    WE      0   2001     10    MY   NaN
# 4  0030068642     X  70132759    WE      0   2001     10    MY   NaN
#
#    addrnumber  ... customerClassification taxNumber kukla loevm  katr7 kdkg1  \
# 0      593223  ...                    NaN       NaN   NaN   NaN    NaN   NaN
# 1      593413  ...                    NaN       NaN   NaN   NaN    NaN   NaN
# 2      592478  ...                    NaN       NaN   NaN   NaN    NaN   NaN
# 3      594365  ...                    NaN       NaN   NaN   NaN    NaN   NaN
# 4      594187  ...                    NaN       NaN   NaN   NaN    NaN   NaN
#
#   kdkg2 kdkg3  kdkg4 kdkg5
# 0   NaN   NaN    NaN   NaN
# 1   NaN   NaN    NaN   NaN
# ...

# %%
dfk = df[df['kunnr'] == '0030078914']
dfk.to_csv('0030078914.csv')

# %%
kunnrgroup = df.groupby("kunnr")["kunn2"].count()
kunnrgroup = kunnrgroup.sort_values(ascending=False)
kunnrgroup = kunnrgroup.head(10)
kunnrgroup
# Out:
# kunnr
# 0030078914    100
# 0030079750     85
# 0030076280     81
# 0030076222     80
# 0030068028     79
# 0030073208     66
# 0030073299     54
# 0030079096     48
# 0030076025     42
# 0030071873     40
# Name: kunn2, dtype: int64

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=kunnrgroup.index,y=kunnrgroup)
plt.xticks(rotation=90)
plt.xlabel('Customer Code')
plt.ylabel('ShipToCode')
plt.savefig('customercode_to_shiptocode_numbers.jpg')
